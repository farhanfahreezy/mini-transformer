# %%
import pandas as pd

# %%
# Login using e.g. `huggingface-cli login` to access this dataset
splits = {'train': 'LeetCodeDataset-train.jsonl', 'test': 'LeetCodeDataset-test.jsonl'}
df_train = pd.read_json("hf://datasets/newfacade/LeetCodeDataset/" + splits["train"], lines=True)
df_test = pd.read_json("hf://datasets/newfacade/LeetCodeDataset/" + splits["test"], lines=True)

df_train = df_train[['problem_description', 'response']]
df_test = df_test[['problem_description', 'response']]

df_train.to_csv('../data/LeetCodeDataset-train.csv', index=False)
df_test.to_csv('../data/LeetCodeDataset-test.csv', index=False)

# %%
df_train.head()
# Out:
#                                           task_id  question_id difficulty  \
# 0                                         two-sum            1       Easy
# 1                                 add-two-numbers            2     Medium
# 2  longest-substring-without-repeating-characters            3     Medium
# 3                     median-of-two-sorted-arrays            4       Hard
# 4                   longest-palindromic-substring            5     Medium
#
#                                           tags  \
# 0                          [Array, Hash Table]
# 1               [Recursion, Linked List, Math]
# 2         [Hash Table, String, Sliding Window]
# 3   [Array, Binary Search, Divide and Conquer]
# 4  [Two Pointers, String, Dynamic Programming]
#
#                                  problem_description  \
# 0  Given an array of integers nums and an integer...
# 1  You are given two non-empty linked lists repre...
# 2  Given a string s, find the length of the longe...
# ...

# %%
df_train = pd.read_csv('../data/LeetCodeDataset-train.csv')
df_test = pd.read_csv('../data/LeetCodeDataset-test.csv')

# %%
df_train.columns
# Out:
# Index(['problem_description', 'response'], dtype='object')

# %%
df_train.head()
# Out:
#                                  problem_description  \
# 0  Given an array of integers nums and an integer...
# 1  You are given two non-empty linked lists repre...
# 2  Given a string s, find the length of the longe...
# 3  Given two sorted arrays nums1 and nums2 of siz...
# 4  Given a string s, return the longest palindrom...
#
#                                             response
# 0  To solve this problem efficiently, we can use ...
# 1  ```python\n# Definition for singly-linked list...
# 2  ```python\nclass Solution:\n    def lengthOfLo...
# 3  ```python\nfrom typing import List\n\nclass So...
# 4  ```python\nclass Solution:\n    def longestPal...

# %%
subset = df_train.iloc[:400]

# Open a text file in write mode
with open('../data/LeetCodeDataset-train.txt', 'w', encoding='utf-8') as f:
    for i, row in subset.iterrows():
        f.write(str(row['problem_description']) + '\n\n')
        f.write(str(row['response']) + '\n\n')
